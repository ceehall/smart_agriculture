# %% [markdown]
# ## Dataset Overview
#
# This dataset contains`16,411` records of crop-related data, focusing on key environmental conditions and their effect on crop growth stages. The dataset includes information such as soil type, seedling stage, moisture index (MOI), temperature, and humidity. Each row represents a unique crop sample with its corresponding environmental factors and an output result, which can be used for machine learning models to predict crop health or irrigation requirementseal-time data.

# %% [markdown]
# Features:
#
# * **crop ID** : Unique identifier for the crop (categorical)
# * **soil_type** : Type of soil for the crop (e.g., Black Soil, Red Soil)
# * **Seedling Stage** : The growth stage of the crop (e.g., Germination)
# * **MOI(Moisture Index)** : The soil moisture content at the time of data collection (integer)
# * **temp(Temperature)** : The ambient temperature in degrees Celsius (integer)
# * **humidity** : The relative humidity in percentage (float)
# * **result** : Indicates whether the crop requires irrigation or not (binary: 1 = yes, 0 = no)

# %% [markdown]
# Potential Use Cases
#
# * **Irrigation management**: This dataset can be used to train models that predict the need for irrigation based on environmental conditio
# * **Agriculture research**: Researchers can use this dataset to study the influence of soil and climate conditions on crop growth stag
# * **Smart farming applications**: Can be integrated into IoT systems for automating irrigation decisions based on real-time daa.

# %% [markdown]
# ## Importing Required Libraries

# %%
## Manipulation Packages
import numpy as np
import pandas as pd

# Visualization Packages
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns

## Model Building Packages
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import OneHotEncoder

print('All packages have been loaded successfully!!!')
# Out:
# All packages have been loaded successfully!!!

# %% [markdown]
# ## Loading The Data and Dataset Overview

# %%
### Loading the data
agric_df = pd.read_csv('cropdata_updated.csv')
agric_df.head()
# Out:
#   crop ID   soil_type Seedling Stage  MOI  temp  humidity  result
# 0   Wheat  Black Soil    Germination    1    25      80.0       1
# 1   Wheat  Black Soil    Germination    2    26      77.0       1
# 2   Wheat  Black Soil    Germination    3    27      74.0       1
# 3   Wheat  Black Soil    Germination    4    28      71.0       1
# 4   Wheat  Black Soil    Germination    5    29      68.0       1

# %%
## Checking for the number of rows and columns
print(f'Our data has {agric_df.shape[0]} rows and {agric_df.shape[1]} columns')
# Out:
# Our data has 16411 rows and 7 columns

# %%
## Checking DataTypes
agric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16411 entries, 0 to 16410
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   crop ID         16411 non-null  object
#  1   soil_type       16411 non-null  object
#  2   Seedling Stage  16411 non-null  object
#  3   MOI             16411 non-null  int64
#  4   temp            16411 non-null  int64
#  5   humidity        16411 non-null  float64
#  6   result          16411 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 897.6+ KB

# %%
## Checking for null values
print('='*80)
print('There were no missing values found in our dataset')
print('='*80)
agric_df.isna().sum()
# Out:
# ================================================================================
# There were no missing values found in our dataset
# ================================================================================
# crop ID           0
# soil_type         0
# Seedling Stage    0
# MOI               0
# temp              0
# humidity          0
# result            0
# dtype: int64

# %%
## Checking for duplicates
print('='*80)
print(f'We have {agric_df.duplicated().sum()} duplicate values in our dataset')
print('='*80)
print('Further preprocessing or cleaning for duplicated values should be considered')
# Out:
# ================================================================================
# We have 128 duplicate values in our dataset
# ================================================================================
# Further preprocessing or cleaning for duplicated values should be considered

# %%
## Dropping Duplicates
agric_df.drop_duplicates(keep='first',inplace=True)

# %%
agric_df.head()
# Out:
#   crop ID   soil_type Seedling Stage  MOI  temp  humidity  result
# 0   Wheat  Black Soil    Germination    1    25      80.0       1
# 1   Wheat  Black Soil    Germination    2    26      77.0       1
# 2   Wheat  Black Soil    Germination    3    27      74.0       1
# 3   Wheat  Black Soil    Germination    4    28      71.0       1
# 4   Wheat  Black Soil    Germination    5    29      68.0       1

# %%
agric_df.shape
# Out:
# (16283, 7)

# %%
## Renaming Columns With The Appropriate Names
agric_df.rename(columns={'crop ID':'crop_name',
                   'Seedling Stage':'seedling_stage',
                  'MOI':'moi'},inplace=True)
agric_df.columns
# Out:
# Index(['crop_name', 'soil_type', 'seedling_stage', 'moi', 'temp', 'humidity',
#        'result'],
#       dtype='object')

# %%
agric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16283 entries, 0 to 16410
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   crop_name       16283 non-null  object
#  1   soil_type       16283 non-null  object
#  2   seedling_stage  16283 non-null  object
#  3   moi             16283 non-null  int64
#  4   temp            16283 non-null  int64
#  5   humidity        16283 non-null  float64
#  6   result          16283 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1017.7+ KB

# %% [markdown]
# ## EDA and Visualization

# %%
#3 Summary Statistics on Numeric Varibales
print('Suumary Statistics On Numeric Variables')
print('='*80)
numeric_columns =  ['moi','temp','humidity']
display(agric_df[numeric_columns].describe())
print('='*80)
# Out:
# Suumary Statistics On Numeric Variables
# ================================================================================
#                 moi          temp      humidity
# count  16283.000000  16283.000000  16283.000000
# mean      43.781858     28.912547     63.316004
# std       27.198158      9.692754     22.634381
# min        1.000000     13.000000     15.000000
# 25%       21.000000     21.000000     44.000000
# 50%       41.000000     29.000000     69.000000
# 75%       64.000000     37.000000     83.000000
# max      100.000000     46.000000     91.000000
# ================================================================================

# %%
agric_df[['moi','temp','humidity']].corr()
# Out:
#                moi      temp  humidity
# moi       1.000000  0.277150 -0.257437
# temp      0.277150  1.000000 -0.976147
# humidity -0.257437 -0.976147  1.000000

# %%
## Summary Statistics on the Cagegorical Columns
print('Summary Statistics on the Categorical Columns')
print('='*80)
categorical_columns = ['crop_name','soil_type','seedling_stage'] 
display(agric_df[categorical_columns].describe(include='object'))
print('='*80)
# Out:
# Summary Statistics on the Categorical Columns
# ================================================================================
#        crop_name  soil_type seedling_stage
# count      16283      16283          16283
# unique         5          7              8
# top        Wheat  Clay Soil      Flowering
# freq        6213       3667           2933
# ================================================================================

# %%
agric_df['crop_name'].unique()
# Out:
# array(['Wheat', 'Potato', 'Carrot', 'Tomato', 'Chilli'], dtype=object)

# %%
agric_df['seedling_stage'].unique()
# Out:
# array(['Germination', 'Seedling Stage',
#        'Vegetative Growth / Root or Tuber Development', 'Flowering',
#        'Pollination', 'Fruit/Grain/Bulb Formation', 'Maturation',
#        'Harvest'], dtype=object)

# %%
agric_df['soil_type'].unique()
# Out:
# array(['Black Soil', 'Alluvial Soil', 'Sandy Soil', 'Red Soil',
#        'Clay Soil', 'Loam Soil', 'Chalky Soil'], dtype=object)

# %%
## Distribution of the numerical columns
def distribution_plot(data,column_name,axis_name,suptitle):
    style.use('seaborn-v0_8-darkgrid')
    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    sns.histplot(data=data,x=column_name);
    plt.xlabel(axis_name,fontsize=15,fontweight='bold')
    plt.ylabel('Frequency',fontsize=15,fontweight='bold')
    
    
    plt.subplot(1,2,2)
    sns.boxplot(data=data,y=column_name);
    plt.xlabel(axis_name,fontsize=15,fontweight='bold')
    plt.ylabel('')

    plt.suptitle(suptitle,fontsize=20,fontweight='bold')
    plt.show(block=False)

# %%
#Distribution of the Temperature
print('Univariate Plot Of the Temperature Feature')
print('='*150)
distribution_plot(agric_df,
                  'temp','Temperature',
                 'Univariate Analysis on Temperature')
print('='*150)
# Out:
# Univariate Plot Of the Temperature Feature
# ======================================================================================================================================================
# ======================================================================================================================================================

# %%
## Humidity
print('Univariate Plot on The Humidty Feature')
print('='*150)
distribution_plot(agric_df,
                  'humidity',
                  'Humidity',
                 'Univariate Analysis On Humidity')
print('='*150)
# Out:
# Univariate Plot on The Humidty Feature
# ======================================================================================================================================================
# ======================================================================================================================================================

# %%
## MOI
print('Univariate Plot on The Mositure Index')
print('='*150)
distribution_plot(agric_df,'moi',
                  'Moisture Index',
             'Univariate Analysis on Mositure Index')
print('='*150)
# Out:
# Univariate Plot on The Mositure Index
# ======================================================================================================================================================
# ======================================================================================================================================================

# %%
agric_df['result'].value_counts(normalize=True)
# Out:
# result
# 0    0.548670
# 1    0.382423
# 2    0.068906
# Name: proportion, dtype: float64

# %%
print('Proportional Distribution of the Target Variable')
print('='*80)
display(sns.barplot(agric_df['result'].value_counts(normalize=True)))
plt.xlabel('Target Categories',fontweight='bold')
plt.ylabel('Proportions Per Category',fontweight='bold')
plt.title('Distribution of Target Based on Proportions',
         fontsize=15,
         fontweight='bold')
plt.show(block=False);
print('='*80)
# Out:
# Proportional Distribution of the Target Variable
# ================================================================================
# <Axes: xlabel='result', ylabel='proportion'>
# ================================================================================

# %%
## Viusualize the target variable
print('Count Plot of The Target Variable')
print('='*80)
sns.countplot(data=agric_df,x='result')
plt.xlabel('Target Categories',fontweight='bold')
plt.ylabel('Counts Per Category',fontweight='bold')
plt.title('Distribution of Target Based on Counts',
         fontsize=15,
         fontweight='bold')
plt.show(block=False)
print('='*80)
# Out:
# Count Plot of The Target Variable
# ================================================================================
# ================================================================================

# %%
unknown_df = agric_df[agric_df['result']==2]
unknown_df.head()
# Out:
#    crop_name   soil_type seedling_stage  moi  temp  humidity  result
# 30     Wheat  Black Soil    Germination   31    33      60.0       2
# 31     Wheat  Black Soil    Germination   32    34      57.5       2
# 32     Wheat  Black Soil    Germination   33    35      55.0       2
# 33     Wheat  Black Soil    Germination   34    36      52.5       2
# 34     Wheat  Black Soil    Germination   35    37      50.0       2

# %%
print('='*80)
print(f'Thenumber of observations with unknown targets are: {unknown_df.shape[0]}')
print('='*80)
# Out:
# ================================================================================
# Thenumber of observations with unknown targets are: 1122
# ================================================================================

# %% [markdown]
# ## Preprocessing and Feature Engineering

# %%
new_agric_df = agric_df[agric_df['result']!= 2]
new_agric_df.head()
# Out:
#   crop_name   soil_type seedling_stage  moi  temp  humidity  result
# 0     Wheat  Black Soil    Germination    1    25      80.0       1
# 1     Wheat  Black Soil    Germination    2    26      77.0       1
# 2     Wheat  Black Soil    Germination    3    27      74.0       1
# 3     Wheat  Black Soil    Germination    4    28      71.0       1
# 4     Wheat  Black Soil    Germination    5    29      68.0       1

# %%
print(f'The number of observations for known labelled is {new_agric_df.shape[0]}')
# Out:
# The number of observations for known labelled is 15161

# %%
sns.countplot(x=new_agric_df['result'])
plt.xlabel('Categories',fontweight='bold')
plt.ylabel('Counts',fontweight='bold')
plt.title('Known Target Categories',fontsize=15,
         fontweight='bold');

# %%
X = new_agric_df.drop('result',axis='columns')
y = new_agric_df['result']

# %%
## Splitting into Train and Test
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,test_size=0.2,random_state=42)

# %%
# Prerocessing Of Categorical Columns
preprocessor = ColumnTransformer(
    transformers=[
        (
            'cat',
            OneHotEncoder(drop='first', handle_unknown='ignore'),
            make_column_selector(dtype_include=object)
        )
    ],
    remainder='passthrough'
)

# model = Pipeline([
#     ('prep', preprocessor),
#     ('clf', RandomForestClassifier())
# ])

# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# %%
# encoder =  OneHotEncoder(drop='first',handle_unknown='ignore',
#                         sparse_output=False)
# X_train_encoded = encoder.fit_transform(X_train)
# X_test_encoded = encoder.transform(X_test)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Building Our Baseline Models

# %%
## Logistic Regression
lr = Pipeline([
    ('prep', preprocessor),
    ('clf', LogisticRegression())
])
lr.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', LogisticRegression())])

# %%
## Decision Tree
dt = Pipeline([
    ('prep', preprocessor),
    ('clf', DecisionTreeClassifier())
])
dt.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', DecisionTreeClassifier())])

# %%
## Knn
knn = Pipeline([
    ('prep', preprocessor),
    ('clf', KNeighborsClassifier())
])
knn.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', KNeighborsClassifier())])

# %%
## RandomForest
rf =Pipeline([
    ('prep', preprocessor),
    ('clf', RandomForestClassifier())
])
rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', RandomForestClassifier())])

# %%
## GradientBoosting
gdb = Pipeline([
    ('prep', preprocessor),
    ('clf', XGBClassifier())
])
gdb.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_by...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
## A simple check on Logistic
def baseline_model_training(model_name,model):
    model_train_accuracy= model.score(X_train,y_train)
    model_test_accuracy = model.score(X_test,y_test)
    print(f'Accuracy on train for {model_name} is: {model_train_accuracy:.4f}, Accuracy on test for {model_name} is: {model_test_accuracy:.4f}')
    # return model_train_accuracy, model_test_accuracy

# %%
## A simple check on Decision Tree
baseline_model_training('Linear Regression',lr)
baseline_model_training('KNN',knn)
baseline_model_training('Decision Tree',dt)
baseline_model_training('RandomForest',rf)
baseline_model_training('Gradient Boosting',gdb)
# Out:
# Accuracy on train for Linear Regression is: 0.8500, Accuracy on test for Linear Regression is: 0.8559
# Accuracy on train for KNN is: 0.9698, Accuracy on test for KNN is: 0.9568
# Accuracy on train for Decision Tree is: 1.0000, Accuracy on test for Decision Tree is: 1.0000
# Accuracy on train for RandomForest is: 1.0000, Accuracy on test for RandomForest is: 0.9990
# Accuracy on train for Gradient Boosting is: 1.0000, Accuracy on test for Gradient Boosting is: 1.0000

# %% [markdown]
# ### HyperParameter Tuning

# %%
## Hyperparameter Tuning For Logistic Regression
lr_params = {'clf__C': [0.1, 0.01, 0.001],
            'clf__max_iter': [50, 70]}

lr_rand = RandomizedSearchCV(
    estimator=lr,
    param_distributions= lr_params,
    cv=5,
    n_jobs= -1
)

# %%
lr_rand.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                                              ('clf', LogisticRegression())]),
#                    n_jobs=-1,
#                    param_distributions={'clf__C': [0.1, 0.01, 0.001],
#                                         'clf__max_iter': [50, 70]})

# %%
print(f'Best estimator:{lr_rand.best_estimator_},\nBest parameters {lr_rand.best_params_}, \nBest Acurracy {lr_rand.best_score_}')
# Out:
# Best estimator:Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129BF89A10>)])),
#                 ('clf', LogisticRegression(C=0.001, max_iter=70))]),
# Best parameters {'clf__max_iter': 70, 'clf__C': 0.001},
# Best Acurracy 0.8683210579546323

# %%
## Hyperparameter Tuning For Decision Tree
dt_params = { 'clf__max_depth': [5, 10, 20],
            'clf__min_samples_split': [2, 5, 10]}
dt_rand = RandomizedSearchCV(
    estimator=dt,
    param_distributions= dt_params,
    cv=5,
    n_jobs= -1
)

# %%
dt_rand.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                                              ('clf',
#                                               DecisionTreeClassifier())]),
#                    n_jobs=-1,
#                    param_distributions={'clf__max_depth': [5, 10, 20],
#                                         'clf__min_samples_split': [2, 5, 10]})

# %%
print('Best Estimators and Parameters on GridSearch and Randomized Search')
print('='*80)
print(f'Best estimator:{dt_rand.best_estimator_},\nBest parameters {dt_rand.best_params_}, \nBest Acurracy {dt_rand.best_score_}')
print('='*80)
# print(f'Best estimator:{dt_rand.best_estimator_},\nBest parameters {dt_rand.best_params_}, \nBest Acurracy {dt_rand.best_score_}')
# Out:
# Best Estimators and Parameters on GridSearch and Randomized Search
# ================================================================================
# Best estimator:Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C8CA5D0>)])),
#                 ('clf', DecisionTreeClassifier(max_depth=20))]),
# Best parameters {'clf__min_samples_split': 2, 'clf__max_depth': 20},
# Best Acurracy 0.999093021476955
# ================================================================================

# %%
## Hyperparameter Tuning For KNN
knn_params = {'clf__n_neighbors': [5, 10, 15],
            'clf__metric': ['euclidean']}
knn_rand = RandomizedSearchCV(
    estimator=knn,
    param_distributions= knn_params,
    cv=5,
    n_jobs= -1
)

# %%
knn_rand.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                                              ('clf', KNeighborsClassifier())]),
#                    n_jobs=-1,
#                    param_distributions={'clf__metric': ['euclidean'],
#                                         'clf__n_neighbors': [5, 10, 15]})

# %%
print('Best Estimators and Parameters on GridSearch and Randomized Search')
print('='*80)
print(f'Best estimator:{knn_rand.best_estimator_}\nBest parameters {knn_rand.best_params_}\nBest Acurracy {knn_rand.best_score_}')
print('='*80)
# print(f'Best estimator:{knn_rand.best_estimator_},\nBest parameters {knn_rand.best_params_}, \nBest Acurracy {knn_rand.best_score_}')
# Out:
# Best Estimators and Parameters on GridSearch and Randomized Search
# ================================================================================
# Best estimator:Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C84E290>)])),
#                 ('clf', KNeighborsClassifier(metric='euclidean'))])
# Best parameters {'clf__n_neighbors': 5, 'clf__metric': 'euclidean'}
# Best Acurracy 0.9569592303312057
# ================================================================================

# %%
## Hyperparameter Tuning For RandomForest 
rf_params = {'clf__n_estimators': [50, 100, 150],
            'clf__max_depth': [5, 10, 20]}

rf_rand = RandomizedSearchCV(
    estimator=rf,
    param_distributions= rf_params,
    cv=5,
    n_jobs= -1
)

# %%
rf_rand.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                                              ('clf',
#                                               RandomForestClassifier())]),
#                    n_jobs=-1,
#                    param_distributions={'clf__max_depth': [5, 10, 20],
#                                         'clf__n_estimators': [50, 100, 150]})

# %%
print('Best Estimators and Parameters on GridSearch and Randomized Search')
print('='*80)
print(f'Best estimator:{rf_rand.best_estimator_}\nBest parameters {rf_rand.best_params_}\nBest Acurracy {rf_rand.best_score_}')
print('='*80)
# print(f'Best estimator:{rf_rand.best_estimator_},\nBest parameters {rf_rand.best_params_}, \nBest Acurracy {rf_rand.best_score_}')
# Out:
# Best Estimators and Parameters on GridSearch and Randomized Search
# ================================================================================
# Best estimator:Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129BF86C50>)])),
#                 ('clf',
#                  RandomForestClassifier(max_depth=20, n_estimators=150))])
# Best parameters {'clf__n_estimators': 150, 'clf__max_depth': 20}
# Best Acurracy 0.9986808203227918
# ================================================================================

# %%
## Hyperparameter Tuning For Gradient Boosting
gdb_params = {'clf__n_estimators': [50, 100, 150], 
            'clf__max_depth': [3, 5, 10],
            'clf__min_samples_split': [2, 5, 10]}


gdb_rand = RandomizedSearchCV(
    estimator=gdb,
    param_distributions= gdb_params,
    cv=5,
    n_jobs= -1
)

# %%
gdb_rand.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:48:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "min_samples_split" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                                              ('clf',
#                                               XGBClassifier(base_score=None,
#                                                             booster=None,
#                                                             callbacks=None,
#                                                             colsample_bylevel=None,...
#                                                             max_cat_threshold=None,
#                                                             max_cat_to_onehot=None,
#                                                             max_delta_step=None,
#                                                             max_depth=None,
#                                                             max_leaves=None,
#                                                             min_child_weight=None,
#                                                             missing=nan,
#                                                             monotone_constraints=None,
#                                                             multi_strategy=None,
#                                                             n_estimators=None,
#                                                             n_jobs=None,
#                                                             num_parallel_tree=None, ...))]),
#                    n_jobs=-1,
#                    param_distributions={'clf__max_depth': [3, 5, 10],
#                                         'clf__min_samples_split': [2, 5, 10],
#                                         'clf__n_estimators': [50, 100, 150]})

# %%
print(' Best Estimators and Parameters on GridSearch and Randomized Search')
print('='*80)
print(f'Best estimator:{gdb_rand.best_estimator_},\nBest parameters {gdb_rand.best_params_}, \nBest Acurracy {gdb_rand.best_score_}')
print('='*80)
# print(f'Best estimator:{gdb_rand.best_estimator_},\nBest parameters {gdb_rand.best_params_}, \nBest Acurracy {gdb_rand.best_score_}')
# Out:
#  Best Estimators and Parameters on GridSearch and Randomized Search
# ================================================================================
# Best estimator:Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129FC62A10>)])),
#                 ('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_by...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, min_samples_split=5,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=100,
#                                n_jobs=None, ...))]),
# Best parameters {'clf__n_estimators': 100, 'clf__min_samples_split': 5, 'clf__max_depth': 5},
# Best Acurracy 1.0
# ================================================================================

# %% [markdown]
# ### Best Model

# %%
lr_rand.best_params_
# Out:
# {'clf__max_iter': 70, 'clf__C': 0.001}

# %%
## Final Model for Logistics Regression

final_lr = Pipeline([
    ('prep', preprocessor),
    ('clf', LogisticRegression(max_iter= 70,C= 0.001))
])
final_lr.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', LogisticRegression(C=0.001, max_iter=70))])

# %%
knn_rand.best_params_
# Out:
# {'clf__n_neighbors': 5, 'clf__metric': 'euclidean'}

# %%
## Final Model for KNN
final_knn = Pipeline([
    ('prep', preprocessor),
    ('clf', KNeighborsClassifier(metric='euclidean',n_neighbors=5))
])
final_knn.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', KNeighborsClassifier(metric='euclidean'))])

# %%
rf_rand.best_params_
# Out:
# {'clf__n_estimators': 150, 'clf__max_depth': 20}

# %%
## Final Model for RandomForest

final_rf = Pipeline([
    ('prep', preprocessor),
    ('clf', RandomForestClassifier(max_depth= 20, n_estimators= 150))
])
final_rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf',
#                  RandomForestClassifier(max_depth=20, n_estimators=150))])

# %%
dt_rand.best_params_
# Out:
# {'clf__min_samples_split': 2, 'clf__max_depth': 20}

# %%
## Final Model for Decision Tree

final_dt = Pipeline([
    ('prep', preprocessor),
    ('clf', DecisionTreeClassifier(max_depth = 20,min_samples_split = 2))
])
final_dt.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf', DecisionTreeClassifier(max_depth=20))])

# %%
gdb_rand.best_params_
# Out:
# {'clf__n_estimators': 100, 'clf__min_samples_split': 5, 'clf__max_depth': 5}

# %%
## Final Model for Gradient Boosting
final_gdb = Pipeline([
    ('prep', preprocessor),
    ('clf', XGBClassifier(max_depth= 5, min_samples_split = 2, n_estimators = 100))
])
final_gdb.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:48:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "min_samples_split" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129C749310>)])),
#                 ('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_by...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, min_samples_split=2,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=100,
#                                n_jobs=None, ...))])

# %% [markdown]
# ## Evaluation

# %%
## Predicting with Logitics Regression Model
final_ypred_lr = final_lr.predict(X_test)
lr_confusion = confusion_matrix(y_test,final_ypred_lr)

# %%
## Confusion Matrix For Logistic Regression
def confusion_matrix_plot(confusion_matrix,title):
    sns.heatmap(lr_confusion,annot=True,
                cmap='viridis',fmt='d',cbar=False)
    plt.title(title,fontweight='bold',fontsize=20)
    plt.xlabel('Predicted',fontweight='bold')
    plt.ylabel('Actual',fontweight='bold');
    
confusion_matrix_plot(lr_confusion,'Confusion Matrix For Logistic Regression')

# %%
## Predicting with KNN Model
final_ypred_knn = final_knn.predict(X_test)
knn_confusion = confusion_matrix(y_test,final_ypred_knn)
## Confusion Matrix For KNN
confusion_matrix_plot(knn_confusion,'Confusion Matrix For KNeighbors')

# %%
## Predicting with Decision Tree Model
final_ypred_dt = final_dt.predict(X_test)
dt_confusion = confusion_matrix(y_test,final_ypred_dt)
## Confusion Matrix For Decision Tree
confusion_matrix_plot(dt_confusion,'Confusion Matrix For Decision Tree')

# %%
## Predicting with RandomForest Model
final_ypred_rf = final_rf.predict(X_test)
rf_confusion = confusion_matrix(y_test,final_ypred_rf)
## Confusion Matrix For Random Forest
confusion_matrix_plot(rf_confusion,'Confusion Matrix For RandomForest')

# %%
## Predicting with GradientBoosting Model
final_ypred_gdb = final_gdb.predict(X_test)
gdb_confusion = confusion_matrix(y_test,final_ypred_gdb)
## Confusion Matrix For Gradient Boosting
confusion_matrix_plot(gdb_confusion,'Confusion Matrix For GradientBoosting')

# %%
# AUC For The Various Models
lr_auc = roc_auc_score(final_ypred_lr,y_test)
knn_auc = roc_auc_score(final_ypred_knn,y_test)
dt_auc = roc_auc_score(final_ypred_dt,y_test)
rf_auc = roc_auc_score(final_ypred_rf,y_test)
gdb_auc = roc_auc_score(final_ypred_gdb,y_test)

lr_auc,knn_auc,dt_auc,rf_auc,gdb_auc
# Out:
# (0.8713463098134632, 0.9544359787300414, 1.0, 0.999198717948718, 1.0)

# %%
# ROC Curve Displaying The Various Model
lr_prob = final_lr.predict_proba(X_test)[:, 1]
knn_prob = final_knn.predict_proba(X_test)[:, 1]
dt_prob = final_dt.predict_proba(X_test)[:, 1]
rf_prob = final_rf.predict_proba(X_test)[:, 1]
gdb_prob = final_gdb.predict_proba(X_test)[:, 1]

lr_fpr, lr_tpr, lr_thresholds = roc_curve(y_test, lr_prob, pos_label=1)
knn_fpr, knn_tpr, knn_thresholds = roc_curve(y_test, knn_prob, pos_label=1)
dt_fpr, dt_tpr, dt_thresholds = roc_curve(y_test, dt_prob, pos_label=1)
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, rf_prob, pos_label=1)
gdb_fpr, gdb_tpr, gdb_thresholds = roc_curve(y_test, gdb_prob, pos_label=1)


plt.figure(figsize=(8, 6))
plt.plot(lr_fpr, lr_tpr, color='black', lw=2, label=f'Logistic Regression(AUC = {lr_auc:.5f})')
plt.plot(knn_fpr, knn_tpr, color='red', lw=2, label=f'KNearest Neighbor (AUC = {knn_auc:.5f})')
plt.plot(dt_fpr, dt_tpr, color='yellow', lw=2, label=f'Decision Tree(AUC = {dt_auc:.5f})')
plt.plot(rf_fpr, rf_tpr, color='blue', lw=2, label=f'Random Forest(AUC = {rf_auc:.5f})')
plt.plot(gdb_fpr, gdb_tpr, color='navy', lw=2, label=f'Gradient Boosting(AUC = {gdb_auc:.5f})')
plt.plot([0, 1], [0, 1], color='purple', lw=2, linestyle='--')
plt.xlabel('False Positive Rate',fontweight='bold')
plt.ylabel('True Positive Rate',fontweight='bold')
plt.title('ROC curve of the models',
          fontsize=15,
          fontweight='bold')
plt.legend(loc="lower right")
plt.show()

# %%
## Building a pipeline
preprocessor = ColumnTransformer(
    transformers=[
        (
            'cat',
            OneHotEncoder(drop='first', handle_unknown='ignore'),
            make_column_selector(dtype_include=object)
        )
    ],
    remainder='passthrough'
)
pipe = Pipeline([('ohe',preprocessor),
    ('xgb',XGBClassifier(n_estimators=100, min_samples_split=5, max_depth=10))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:23:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "min_samples_split" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Pipeline(steps=[('ohe',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002129FD04590>)])),
#                 ('xgb',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_byt...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=10, max_leaves=None,
#                                min_child_weight=None, min_samples_split=5,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=100,
#                                n_jobs=None, ...))])

# %%
pipe.score(X_train,y_train)
# Out:
# 1.0

# %%
pipe.score(X_test,y_test)
# Out:
# 1.0

# %%
# Get the feature names from the encoder step
column_names = pipe.named_steps['ohe'].get_feature_names_out()

# Get importance from the model
importances = pipe.named_steps['xgb'].feature_importances_

# Combine them into a readable format
feature_importance_df = pd.DataFrame({
    'feature': column_names,
    'importance': importances
}).sort_values(by='importance', ascending=False)
feature_importance_df.reset_index(drop=True,inplace=True)

# %%
feature_importance_df.head()
# Out:
#                                              feature  importance
# 0                                    remainder__temp    0.717510
# 1                                     remainder__moi    0.140923
# 2                              cat__crop_name_Chilli    0.029880
# 3                               cat__crop_name_Wheat    0.020731
# 4  cat__seedling_stage_Vegetative Growth / Root o...    0.019777

# %%
test_unknown = unknown_df.drop('result',axis='columns')
test_unknown.head()
# Out:
#    crop_name   soil_type seedling_stage  moi  temp  humidity
# 30     Wheat  Black Soil    Germination   31    33      60.0
# 31     Wheat  Black Soil    Germination   32    34      57.5
# 32     Wheat  Black Soil    Germination   33    35      55.0
# 33     Wheat  Black Soil    Germination   34    36      52.5
# 34     Wheat  Black Soil    Germination   35    37      50.0

# %%
pipe.predict_proba(test_unknown)
# Out:
# array([[0.0051803 , 0.9948197 ],
#        [0.00443047, 0.9955695 ],
#        [0.00431514, 0.99568486],
#        ...,
#        [0.99880564, 0.00119433],
#        [0.99880564, 0.00119433],
#        [0.99880564, 0.00119433]], dtype=float32)
